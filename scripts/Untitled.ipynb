# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
totoro = cv2.imread('totoroOrig.jpg')

# %%
plt.imshow(totoro)
plt.show()

# %%
totoro = cv2.cvtColor(totoro, cv2.COLOR_BGR2RGB)
plt.imshow(totoro)
plt.show()

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-7b899824b39e> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-101> in matplotlib(self, line)
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

r, g, b = cv2.split(totoro)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")

pixel_colors = totoro.reshape((np.shape(totoro)[0]*np.shape(totoro)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()

# %%
totoro = cv2.cvtColor(totoro, cv2.COLOR_RGB2HSV)
plt.imshow(totoro)
plt.show()
